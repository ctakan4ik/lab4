# %%
# !pip install catboost
# Out:
# ...
#      ---------------------------------------- 74.0/74.0 MB 3.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 47.0/47.0 kB ? eta 0:00:00
# ...

# %%
import numpy as np

from catboost.datasets import titanic

# %%
train_df = titanic()[0]

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.to_csv('datasets/titanic.csv',index=True)

# %%
train_df = train_df.drop(columns = ["Survived","Name","SibSp","Parch", "Ticket", "Fare", "Cabin",'Embarked'], axis = 1)

# %%
train_df
# Out:
#      PassengerId  Pclass     Sex   Age
# 0              1       3    male  22.0
# 1              2       1  female  38.0
# 2              3       3  female  26.0
# 3              4       1  female  35.0
# 4              5       3    male  35.0
# ..           ...     ...     ...   ...
# 886          887       2    male  27.0
# 887          888       1  female  19.0
# 888          889       3  female   NaN
# 889          890       1    male  26.0
# 890          891       3    male  32.0
#
# [891 rows x 4 columns]

# %%
train_df.to_csv('datasets/titanic.csv',index=True)
